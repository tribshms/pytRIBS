# %% [markdown]
# ## Spin up

# %%
import sys
from datetime import datetime
import os
os.chdir("../..")


extra_path = "/Users/lraming/Documents/Repos/GP4"
if extra_path not in sys.path:
    sys.path.append(extra_path)

from tribsmodel import Model as model

m = model()

# %%
input_file = 'sycMS2.in'

base_name = 'ms2_'

m.read_input_file(input_file)

# gw voi file from intial run will want to update in future
m.options["optgwfile"]["value"] = 1
gwvoi = "results/2023-10-19/ms2_0_gwvoi"
end_time = int(m.options["runtime"]["value"])

# %%
m.check_paths()
# Out:
# The following tRIBS inputs do not have paths that exist:
#
# CHANNELWIDTHFILE: Filename that contains channel widths
# INPUTDATAFILE: tMesh input file base name for Mesh files
# ARCINFOFILENAME: tMesh input file base name Arc files
# RAINFILE: Base name of the radar ASCII grid
# RAINEXTENSION: Extension for the radar ASCII grid
# SCGRID: Soil grid data file (*.gdf). Note OPTSOILTYPE must = 1 if inputing soil grids
# HYDROMETCONVERT: Hydrometeorological data conversion file (*.mdi)
# GAUGECONVERT: Rain Gauge data conversion file (*.mdi)
# GAUGEBASENAME:  Rain Gauge data BASE name (*.mdf)
# OUTHYDROEXTENSION: Extension for hydrograph output
# RIBSHYDOUTPUT: compatibility with RIBS User Interphase
# NODEOUTPUTLIST: Filename with Nodes for Dynamic Output (*.nol)
# HYDRONODELIST: Filename with Nodes for HydroModel Output (*.nol)
# OUTLETNODELIST: Filename with Interior Nodes for  Output (*.nol)
# OUTFILENAME: Base name of the tMesh and variable
# OUTHYDROFILENAME: Base name for hydrograph output
# FORECASTFILE: Base name of the radar QPF grids
# WEATHERTABLENAME: File with Stochastic Weather Table
# RESTARTDIR: Path of directory for restart output
# RESTARTFILE: Actual file to restart a run
# OUTVIZFILENAME: Filename for viz binary files
#
# Checking if station descriptor paths exist.
#
# ...
# All rain gauge paths exist.
# ...
# All met station paths exist.
#
# Checking if grid files exist.
#  ...
#
# Model is set to hydro-met grid files: checking paths and .gdf file
# Warning: Raster file not found for Variable 'TS':
# Warning: Raster file not found for Variable 'XC':
# Warning: Raster file not found for Variable 'NR':
# Warning: Raster file not found for Variable 'TD':
# Warning: Raster file not found for Variable 'VP':
# Warning: The number of variables exceeds the number of parameters. This variable has been reset in dictionary.

# %%
# gw voi file from intial run will want to update in future
m.options["optgwfile"]["value"] = 1
gwvoi = "results/2023-10-19/ms2_0_gwvoi"
end_time = int(m.options["runtime"]["value"])

# Get today's date and make results directory
today = datetime.now().date()
today = today.strftime('%Y-%m-%d')
todays_results = 'results/' + today + '/'

try:
    os.makedirs(todays_results)
except FileExistsError:
    # directory already exists
    pass


# currently just running spinup for 3 years total, but maybe better approach.

iterations = [1, 2]

for i in iterations:
    result_path = todays_results + str(i)
    
    try:
        os.makedirs(result_path)
    except FileExistsError:
        # directory already exists
        pass
  
    outfiles = result_path + '/' + base_name
    m.options["outfilename"]["value"] = outfiles
    m.options["outhydrofilename"]["value"] = outfiles
    m.options['gwaterfile']['value'] = gwvoi
    m.write_input_file(input_file)
    m.run('./tRIBS', input_file, mpi_command='mpirun -n 4')

    # update gwvoi file
    gwvoi = m.options["outfilename"]["value"] + str(i) + "_gwvoi"

    # merger parallel files and write ouyt gwvoi file
    df = m.merge_parllel_spatial_files(dtime=end_time, write=False)
    df = df[str(end_time)]
    df[['ID', 'Nwt']].to_csv(gwvoi, sep='\t', index=False, header=False)
# Out:
# ['time', 'mpirun', '-n', '4', './tRIBS', 'sycMS2.in']
# tParallel: MPI initialized, 4 processor(s).
#
# ------------------------------------------------------------------------
#
# 		 tRIBS Distributed Hydrologic Model
# 		 TIN-based Real-time Integrated Basin Simulator
# 		 Ralph M. Parsons Laboratory
# 		 Massachusetts Institute of Technology
#
# ------------------------------------------------------------------------
#
#
# tRIBS Version 4.0, Fall 2023
#
#
#
# Part 1: Read Input Parameters from 'sycMS2.in'
# ---------------------------------------------------
# Parameter =   OPTGROUNDWATER			1
# Parameter =   OPTSPATIAL			0
# Parameter =   OPTINTERHYDRO			0
# Parameter =   OPTHEADER			1
# Parameter =   STARTDATE			01/01/2016/00/00
# Parameter =   RUNTIME			8760
# Parameter =   TIMESTEP			3.75
# Parameter =   GWSTEP			30
# Parameter =   METSTEP			60
# Parameter =   RAININTRVL			1
# Parameter =   OPINTRVL			1
# Parameter =   SPOPINTRVL			8760
# Parameter =   INTSTORMMAX			1000
# Parameter =   TLINKE			2
# Parameter =   BASEFLOW			0.01
# Parameter =   VELOCITYCOEF			0.6
# Parameter =   VELOCITYRATIO			70
# Parameter =   KINEMVELCOEF			25
# Parameter =   FLOWEXP			0.4
# Parameter =   CHANNELROUGHNESS			0.3
# Parameter =   CHANNELWIDTHCOEFF			2.3
# Parameter =   CHANNELWIDTHEXPNT			0.5
# Parameter =   CHANNELWIDTHFILE
# Parameter =   WIDTHINTERPOLATION			0
# Parameter =   OPTEVAPOTRANS			1
# Parameter =   OPTINTERCEPT			2
# Parameter =   GFLUXOPTION			2
# Parameter =   OPTSNOW			1
# Parameter =   MINSNTEMP			-27
# Parameter =   SNLIQFRAC			0.45
# Parameter =   OPTRADSHELT			2
# Parameter =   OPTMESHINPUT			8
# Parameter =   RAINSOURCE			3
# Parameter =   METDATAOPTION			2
# Parameter =   OPTLANDUSE			0
# Parameter =   CONVERTDATA			0
# Parameter =   OPTBEDROCK			1
# Parameter =   FORECASTMODE			0
# Parameter =   STOCHASTICMODE			0
# Parameter =   OPTRESERVOIR			0
# Parameter =   OPTSOILTYPE			0
# Parameter =   SOILTABLENAME			data/model/2023-10-16/Sycamore_new.sdt
# Parameter =   SOILMAPNAME			data/model/SC_New.txt
# Parameter =   LANDTABLENAME			data/model/Sycamore.ldt
# Parameter =   LANDMAPNAME			data/model/LC.asc
# Parameter =   GWATERFILE			results/2023-10-19/ms2_0_gwvoi
# Parameter =   OPTRADSHELT			2
# Parameter =   DEMFILE			data/model/USGS_DEM_200m_UTM_WGS84_MSSyc.asc
# Parameter =   GAUGESTATIONS			data/model/rain/Rain_MS_2.sdf
# Parameter =   RAINDISTRIBUTION			0
# Parameter =   BEDROCKFILE			data/model/Sycamore.brd
# Parameter =   HYDROMETGRID			data/model/Sycamore_Weather.gdf
# Parameter =   TEMPLAPSE			-0.0065
# Parameter =   PRECLAPSE			0
# Parameter =   HILLALBOPT			2
# Parameter =   OUTFILENAME			results/2023-10-23/1/ms2_
# Parameter =   OUTHYDROFILENAME			results/2023-10-23/1/ms2_
# Parameter =   OUTHYDROEXTENSION			mrf
# Parameter =   NODEOUTPUTLIST
# Parameter =   HYDRONODELIST
# Parameter =   OUTLETNODELIST
# Parameter =   RESTARTMODE			0
# Parameter =   PARALLELMODE			1
# Parameter =   GRAPHOPTION			1
# Parameter =   GRAPHFILE			data/model/parallel_mesh/2023-10-19/sycMS2/sycMS2_flow_4nodes.reach
# Parameter =   OPTVIZ			0
#
# Input File Keywords Checked...
#
# Start TIME: 	YEAR	MONTH	DAY	HOUR	MINUTE
# 		2016	1	1	0	0
#
# Total TIME:	 8760 hours
#
# End TIME: 	YEAR	MONTH	DAY	HOUR	MINUTE
# 		2016	12	31	0	0
#
# Output INTERVAL: 			1 hours
#
# Spatial Output INTERVAL: 		8760 hours
# Rainfall Input TIME STEP: 		1 hours
# Meteorological Input TIME STEP: 	1 hours
# Unsaturated zone TIME STEP: 		3.75 minutes
# Saturated Zone TIME STEP: 		30 minutes
#
#
# Part 2: Creating Mesh from Points File (Option 8)
# ---------------------------------------------------
#
# Reading in 'data/model/points/MS2s1z1_tree_8_1.points' points file...
#
# Computing triangulation...elapsed time (time)= 0 s (clock)= 0.09914 s
# elapsed time (time)= 0 s (clock)= 0.099385 s
# elapsed time (time)= 0 s (clock)= 0.09932 s
# elapsed time (time)= 0 s (clock)= 0.098714 s
#
# Creating edge list...
#
# Setting up spoke lists...
#
# Setting up CCW edges...
#
# Setting up triangle connectivity...
# NODE #2152 ( 399072 , 3.89114e+06 ) is surrounded by closed boundary nodes
# Error in mesh consistency.NODE #2152 ( 399072 , 3.89114e+06 ) is surrounded by closed boundary nodes
# Error in mesh consistency.NODE #2152 ( 399072 , 3.89114e+06 ) is surrounded by closed boundary nodes
# Error in mesh consistency.NODE #2152 ( 399072 , 3.89114e+06 ) is surrounded by closed boundary nodes
# Error in mesh consistency.
# MakeMeshFromTriangulator Successful Using Option 8
#
#
# Part 3: Creating Stream Network from Mesh
# ---------------------------------------------
#
# Calculating slopes...
#
# Initializing flow directions...
#
# Error in InitFlowDirs(): Node 2152 surrounded by closed boundary nodes ...
#
# Node boundary will be changed to kClosedBoundary...
# 2152	399072	3.89114e+06	2221.59	0
#
#
# Computing flow directions...
#
# Correcting sinks...
#
# Sorting nodes by network order...
#
# Renumbering nodes, edges, triangles...
#
# Setting basin outlet and stream reaches...
#
# Basin outlet node determined...
#
# Connect stream nodes by weighted short path...
#
# Sorting stream nodes completed...
# OptRES = 0
# read DEM
#
# Outlet contributing area:	4.772726 km^2
#
# Derived stream reaches...
#
# Initialize velocities and time...
#
#
# Flow Characteristics:
#
# The  Total  Basin  Area is   	4772725.933004 M^2
# Maximum travel time: 		224.238586 hours
# Maximum hillslope path: 	6910.994326 meters
# Maximum stream path: 		585.743470 meters
#
#
# Checking drainage widths...
# tFlowNet: Checking Voronoi drainage widths...
#
# Set reach numbers...
#
# Hillslope velocity: 		0.008571 m/sec
# Stream velocity: 		0.600000 m/sec
# Hydrograph array size: 		8985
#
# Flow Output Files:
#
# Hydrograph File Name: 		'results/2023-10-23/1/ms2_'
# Hydrograph Outlet Name: 		                      ms2_
# Hydrograph File Extension: 	mrf
#
# Channel Characteristics:
#
# Kinematic velocity coefficient: 25.000000
# Roughness coefficient: 		0.300000
# Channel width: 			Variable
#
# Channel widths determined from geomorphic relations...
# Parameter =   OPTRESERVOIR			0.000000
# Parameter =   TIMESTEP			3.750000
# Parameter =   RUNTIME			8760.000000
# OptRES = 0
#
#
# Part 3b: Creating Stream Reach partitioning
# -----------------------------------------------
#
# Creating stream reach connectivity table...
#
# Partitioning stream reach graph...
#
# Partitioning read from reach file data/model/parallel_mesh/2023-10-19/sycMS2/sycMS2_flow_4nodes.reach
#
# Updating stream reach and node list...
# Processed 10000 nodes
# Processed 20000 nodes
# Processed 30000 nodes
# Processed 40000 nodes
# Processed 50000 nodes
# Processed 60000 nodes
# Processed 70000 nodes
# Processed 80000 nodes
# Processed 90000 nodes
# Processed 100000 nodes
#
# Updated node list based on local reaches...
# Processed 50000 edges
# Processed 100000 edges
# Processed 150000 edges
# Processed 200000 edges
# Processed 250000 edges
# Processed 300000 edges
# Processed 350000 edges
# Processed 400000 edges
# Processed 450000 edges
# Processed 500000 edges
# Processed 550000 edges
# Processed 600000 edges
#
# Updated edge list based on local reaches...
#
# Writing connectivity file...
#
#
# Part 4: Creating Resampling Object
# --------------------------------------
#
# tResample: Making boundary polygons...
#
#
# Total Number of Nodes: 		109792
#
# tResample: Making interior polygons...
#
#
# Part 4a: Creating Sheltering Object for DEM Input
# ----------------------------------------------------
#
# tResample: Making boundary polygons...
#
#
# Total Number of Nodes: 		109792
#
# tResample: Making interior polygons...
# read DEM
#
#
# Part 5: Creating Output Files from 'sycMS2.in'
# ------------------------------------------
#
# Output Files:
#
#
# File  not found...
# 	Attention: The specified file with node IDs does not exist.
# 		   No node output will be written.
#
#
# >>>Outlet Node File  not found...
# >>>No output for interior nodes will be written...
#
#
#
# Part 6: Creating Hydrologic System
# --------------------------------------
#
# Resampling soil and land use grids...
# OptRES = 0
# read DEM
# 	The file 'mdf' has been successfully read...
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2L.mdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2U.mdf'...
# OptRES = 0
# read DEM
#
# Hydrologic Options:
#
# Evapotranspiration Option: 	1
# Interception Option: 		2
# Ground Heat Flux Option: 	2
# Bedrock Depth Option: 		1
#
# Resampling depth to bedrock grid...
#
# HydroNodeList File  not found.
# 	Warning: The file with hydro node IDs does not exist. No output will be written.
#
# Creating Rainfall Setup...
# Rainfall Source: 		Raingauge Stations
#
# Reading Rain Gauge Station File 'data/model/rain/Rain_MS_2.sdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2L.mdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2U.mdf'...
#
# Creating EvapoTranspiration Setup...
#
# Creating Interception Setup...
#
# Initializing SnowPack setup...
#
# Creating Restart setup...
#
#
# Part 7: Creating and Initializing Simulation
# ------------------------------------------------
# 	The file 'mdf' has been successfully read...
# 	The file 'mdf' has been successfully read...
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2L.mdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2U.mdf'...
# 	The file 'mdf' has been successfully read...
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2L.mdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2U.mdf'...
# Proc 2: tOutput Characteristics:
# Proc 2: Number of nodes: 		109792
# Proc 2: Number of edges: 		658688
# Proc 2: Number of active nodes: 	15316
# Proc 2: Number of active edges: 	91007
# Proc 2: Number of global active nodes: 	104368
# Proc 2: Number of global active edges: 	622406
# Proc 3: tOutput Characteristics:
# Proc 3: Number of nodes: 		109792
# Proc 3: Number of edges: 		658688
# Proc 3: Number of active nodes: 	35628
# Proc 3: Number of active edges: 	212192
# Proc 3: Number of global active nodes: 	104368
# Proc 3: Number of global active edges: 	622406
# Proc 0: tOutput Characteristics:
# Proc 0: Number of nodes: 		109792
# Proc 0: Number of edges: 		658688
# Proc 0: Number of active nodes: 	37113
# Proc 0: Number of active edges: 	221608
# Proc 0: Number of global active nodes: 	104368
# Proc 0: Number of global active edges: 	622406
# Proc 1: tOutput Characteristics:
# Proc 1: Number of nodes: 		109792
# Proc 1: Number of edges: 		658688
# Proc 1: Number of active nodes: 	16311
# Proc 1: Number of active edges: 	97599
# Proc 1: Number of global active nodes: 	104368
# Proc 1: Number of global active edges: 	622406
#
# 	HOUR = 0	MINUTE = 0
#
# 	HOUR = 0	MINUTE = 0
#
# 	HOUR = 0	MINUTE = 0
#
# 	HOUR = 0	MINUTE = 0
#
# Reading HydroMeteorological Grid File: data/model/Sycamore_Weather.gdf...
#
# Using ID Land-Use Map
#
#
# Part 8: Hydrologic Simulation Loop
# --------------------------------------
#
# Hydrologic Simulation begins...
#
#
# Creating Hydrograph Output: 'results/2023-10-23/1/ms2_8760_00.mrf'
# Creating Runoff Type Output: 'results/2023-10-23/1/ms2_8760_00.rft'
#
# 	HOUR = 8760	MINUTE = 0
#
# 	HOUR = 8760	MINUTE = 0
#
# 	HOUR = 8760	MINUTE = 0
#
# 	HOUR = 8760	MINUTE = 0
# [en4201924-ssebe:46606] *** Process received signal ***
# [en4201924-ssebe:46606] Signal: Segmentation fault: 11 (11)
# [en4201924-ssebe:46606] Signal code: Invalid permissions (2)
# [en4201924-ssebe:46606] Failing at address: 0x0
# [en4201924-ssebe:46606] [ 0] 0   libsystem_platform.dylib            0x0000000186295a24 _sigtramp + 56
# [en4201924-ssebe:46606] [ 1] 0   tRIBS                               0x00000001021be9c0 _ZN11tEvapoTrans16DeleteEvapoTransEv + 128
# [en4201924-ssebe:46606] [ 2] 0   tRIBS                               0x00000001021befe4 _ZN11tEvapoTransD1Ev + 20
# [en4201924-ssebe:46606] [ 3] 0   tRIBS                               0x0000000102161578 _Z18parallelSimulationiPPc + 4156
# [en4201924-ssebe:46606] [ 4] 0   tRIBS                               0x0000000102160530 main + 12
# [en4201924-ssebe:46606] [ 5] 0   dyld                                0x0000000185eed058 start + 2224
# [en4201924-ssebe:46606] *** End of error message ***
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# [en4201924-ssebe:46604] *** Process received signal ***
# [en4201924-ssebe:46604] Signal: Segmentation fault: 11 (11)
# [en4201924-ssebe:46604] Signal code: Invalid permissions (2)
# [en4201924-ssebe:46604] Failing at address: 0x0
# [en4201924-ssebe:46604] [ 0] 0   libsystem_platform.dylib            0x0000000186295a24 _sigtramp + 56
# [en4201924-ssebe:46604] [ 1] 0   tRIBS                               0x000000010255e9c0 _ZN11tEvapoTrans16DeleteEvapoTransEv + 128
# [en4201924-ssebe:46604] [ 2] 0   tRIBS                               0x000000010255efe4 _ZN11tEvapoTransD1Ev + 20
# [en4201924-ssebe:46604] [ 3] 0   tRIBS                               0x0000000102501578 _Z18parallelSimulationiPPc + 4156
# [en4201924-ssebe:46604] [ 4] 0   tRIBS                               0x0000000102500530 main + 12
# [en4201924-ssebe:46604] [ 5] 0   dyld                                0x0000000185eed058 start + 2224
# [en4201924-ssebe:46604] *** End of error message ***
# [en4201924-ssebe:46605] *** Process received signal ***
# [en4201924-ssebe:46605] Signal: Segmentation fault: 11 (11)
# [en4201924-ssebe:46605] Signal code: Invalid permissions (2)
# [en4201924-ssebe:46605] Failing at address: 0x0
# [en4201924-ssebe:46605] [ 0] 0   libsystem_platform.dylib            0x0000000186295a24 _sigtramp + 56
# [en4201924-ssebe:46605] [ 1] 0   tRIBS                               0x00000001009229c0 _ZN11tEvapoTrans16DeleteEvapoTransEv + 128
# [en4201924-ssebe:46605] [ 2] 0   tRIBS                               0x0000000100922fe4 _ZN11tEvapoTransD1Ev + 20
# [en4201924-ssebe:46605] [ 3] 0   tRIBS                               0x00000001008c5578 _Z18parallelSimulationiPPc + 4156
# [en4201924-ssebe:46605] [ 4] 0   tRIBS                               0x00000001008c4530 main + 12
# [en4201924-ssebe:46605] [ 5] 0   dyld                                0x0000000185eed058 start + 2224
# [en4201924-ssebe:46605] *** End of error message ***
# [en4201924-ssebe:46607] *** Process received signal ***
# [en4201924-ssebe:46607] Signal: Segmentation fault: 11 (11)
# [en4201924-ssebe:46607] Signal code: Invalid permissions (2)
# [en4201924-ssebe:46607] Failing at address: 0x0
# [en4201924-ssebe:46607] [ 0] 0   libsystem_platform.dylib            0x0000000186295a24 _sigtramp + 56
# [en4201924-ssebe:46607] [ 1] 0   tRIBS                               0x00000001043de9c0 _ZN11tEvapoTrans16DeleteEvapoTransEv + 128
# [en4201924-ssebe:46607] [ 2] 0   tRIBS                               0x00000001043defe4 _ZN11tEvapoTransD1Ev + 20
# [en4201924-ssebe:46607] [ 3] 0   tRIBS                               0x0000000104381578 _Z18parallelSimulationiPPc + 4156
# [en4201924-ssebe:46607] [ 4] 0   tRIBS                               0x0000000104380530 main + 12
# [en4201924-ssebe:46607] [ 5] 0   dyld                                0x0000000185eed058 start + 2224
# [en4201924-ssebe:46607] *** End of error message ***
# --------------------------------------------------------------------------
# mpirun noticed that process rank 2 with PID 0 on node en4201924-ssebe exited on signal 11 (Segmentation fault: 11).
# --------------------------------------------------------------------------
#     14471.98 real     57612.71 user       170.54 sys
# ['time', 'mpirun', '-n', '4', './tRIBS', 'sycMS2.in']
# tParallel: MPI initialized, 4 processor(s).
#
# ------------------------------------------------------------------------
#
# 		 tRIBS Distributed Hydrologic Model
# 		 TIN-based Real-time Integrated Basin Simulator
# 		 Ralph M. Parsons Laboratory
# 		 Massachusetts Institute of Technology
#
# ------------------------------------------------------------------------
#
#
# tRIBS Version 4.0, Fall 2023
#
#
#
# Part 1: Read Input Parameters from 'sycMS2.in'
# ---------------------------------------------------
# Parameter =   OPTGROUNDWATER			1
# Parameter =   OPTSPATIAL			0
# Parameter =   OPTINTERHYDRO			0
# Parameter =   OPTHEADER			1
# Parameter =   STARTDATE			01/01/2016/00/00
# Parameter =   RUNTIME			8760
# Parameter =   TIMESTEP			3.75
# Parameter =   GWSTEP			30
# Parameter =   METSTEP			60
# Parameter =   RAININTRVL			1
# Parameter =   OPINTRVL			1
# Parameter =   SPOPINTRVL			8760
# Parameter =   INTSTORMMAX			1000
# Parameter =   TLINKE			2
# Parameter =   BASEFLOW			0.01
# Parameter =   VELOCITYCOEF			0.6
# Parameter =   VELOCITYRATIO			70
# Parameter =   KINEMVELCOEF			25
# Parameter =   FLOWEXP			0.4
# Parameter =   CHANNELROUGHNESS			0.3
# Parameter =   CHANNELWIDTHCOEFF			2.3
# Parameter =   CHANNELWIDTHEXPNT			0.5
# Parameter =   CHANNELWIDTHFILE
# Parameter =   WIDTHINTERPOLATION			0
# Parameter =   OPTEVAPOTRANS			1
# Parameter =   OPTINTERCEPT			2
# Parameter =   GFLUXOPTION			2
# Parameter =   OPTSNOW			1
# Parameter =   MINSNTEMP			-27
# Parameter =   SNLIQFRAC			0.45
# Parameter =   OPTRADSHELT			2
# Parameter =   OPTMESHINPUT			8
# Parameter =   RAINSOURCE			3
# Parameter =   METDATAOPTION			2
# Parameter =   OPTLANDUSE			0
# Parameter =   CONVERTDATA			0
# Parameter =   OPTBEDROCK			1
# Parameter =   FORECASTMODE			0
# Parameter =   STOCHASTICMODE			0
# Parameter =   OPTRESERVOIR			0
# Parameter =   OPTSOILTYPE			0
# Parameter =   SOILTABLENAME			data/model/2023-10-16/Sycamore_new.sdt
# Parameter =   SOILMAPNAME			data/model/SC_New.txt
# Parameter =   LANDTABLENAME			data/model/Sycamore.ldt
# Parameter =   LANDMAPNAME			data/model/LC.asc
# Parameter =   GWATERFILE			results/2023-10-23/1/ms2_1_gwvoi
# Parameter =   OPTRADSHELT			2
# Parameter =   DEMFILE			data/model/USGS_DEM_200m_UTM_WGS84_MSSyc.asc
# Parameter =   GAUGESTATIONS			data/model/rain/Rain_MS_2.sdf
# Parameter =   RAINDISTRIBUTION			0
# Parameter =   BEDROCKFILE			data/model/Sycamore.brd
# Parameter =   HYDROMETGRID			data/model/Sycamore_Weather.gdf
# Parameter =   TEMPLAPSE			-0.0065
# Parameter =   PRECLAPSE			0
# Parameter =   HILLALBOPT			2
# Parameter =   OUTFILENAME			results/2023-10-23/2/ms2_
# Parameter =   OUTHYDROFILENAME			results/2023-10-23/2/ms2_
# Parameter =   OUTHYDROEXTENSION			mrf
# Parameter =   NODEOUTPUTLIST
# Parameter =   HYDRONODELIST
# Parameter =   OUTLETNODELIST
# Parameter =   RESTARTMODE			0
# Parameter =   PARALLELMODE			1
# Parameter =   GRAPHOPTION			1
# Parameter =   GRAPHFILE			data/model/parallel_mesh/2023-10-19/sycMS2/sycMS2_flow_4nodes.reach
# Parameter =   OPTVIZ			0
#
# Input File Keywords Checked...
#
# Start TIME: 	YEAR	MONTH	DAY	HOUR	MINUTE
# 		2016	1	1	0	0
#
# Total TIME:	 8760 hours
#
# End TIME: 	YEAR	MONTH	DAY	HOUR	MINUTE
# 		2016	12	31	0	0
#
# Output INTERVAL: 			1 hours
#
# Spatial Output INTERVAL: 		8760 hours
# Rainfall Input TIME STEP: 		1 hours
# Meteorological Input TIME STEP: 	1 hours
# Unsaturated zone TIME STEP: 		3.75 minutes
# Saturated Zone TIME STEP: 		30 minutes
#
#
# Part 2: Creating Mesh from Points File (Option 8)
# ---------------------------------------------------
#
# Reading in 'data/model/points/MS2s1z1_tree_8_1.points' points file...
#
# Computing triangulation...elapsed time (time)= 0 s (clock)= 0.098715 s
# elapsed time (time)= 0 s (clock)= 0.098605 s
# elapsed time (time)= 0 s (clock)= 0.09873 s
# elapsed time (time)= 0 s (clock)= 0.098813 s
#
# Creating edge list...
#
# Setting up spoke lists...
#
# Setting up CCW edges...
#
# Setting up triangle connectivity...
# NODE #2152 ( 399072 , 3.89114e+06 ) is surrounded by closed boundary nodes
# Error in mesh consistency.NODE #2152 ( 399072 , 3.89114e+06 ) is surrounded by closed boundary nodes
# Error in mesh consistency.NODE #2152 ( 399072 , 3.89114e+06 ) is surrounded by closed boundary nodes
# Error in mesh consistency.NODE #2152 ( 399072 , 3.89114e+06 ) is surrounded by closed boundary nodes
# Error in mesh consistency.
# MakeMeshFromTriangulator Successful Using Option 8
#
#
# Part 3: Creating Stream Network from Mesh
# ---------------------------------------------
#
# Calculating slopes...
#
# Initializing flow directions...
#
# Error in InitFlowDirs(): Node 2152 surrounded by closed boundary nodes ...
#
# Node boundary will be changed to kClosedBoundary...
# 2152	399072	3.89114e+06	2221.59	0
#
#
# Computing flow directions...
#
# Correcting sinks...
#
# Sorting nodes by network order...
#
# Renumbering nodes, edges, triangles...
#
# Setting basin outlet and stream reaches...
#
# Basin outlet node determined...
#
# Connect stream nodes by weighted short path...
#
# Sorting stream nodes completed...
#
# Outlet contributing area:	4.772726 km^2
#
# Derived stream reaches...
#
# Initialize velocities and time...
# OptRES = 0
# read DEM
# OptRES = 0
# read DEM
#
#
# Flow Characteristics:
#
# The  Total  Basin  Area is   	4772725.933004 M^2
# Maximum travel time: 		224.238586 hours
# Maximum hillslope path: 	6910.994326 meters
# Maximum stream path: 		585.743470 meters
#
#
# Checking drainage widths...
# tFlowNet: Checking Voronoi drainage widths...
#
# Set reach numbers...
#
# Hillslope velocity: 		0.008571 m/sec
# Stream velocity: 		0.600000 m/sec
# Hydrograph array size: 		8985
#
# Flow Output Files:
#
# Hydrograph File Name: 		'results/2023-10-23/2/ms2_'
# Hydrograph Outlet Name: 		                      ms2_
# Hydrograph File Extension: 	mrf
#
# Channel Characteristics:
#
# Kinematic velocity coefficient: 25.000000
# Roughness coefficient: 		0.300000
# Channel width: 			Variable
#
# Channel widths determined from geomorphic relations...
# Parameter =   OPTRESERVOIR			0.000000
# Parameter =   TIMESTEP			3.750000
# Parameter =   RUNTIME			8760.000000
# OptRES = 0
#
#
# Part 3b: Creating Stream Reach partitioning
# -----------------------------------------------
#
# Creating stream reach connectivity table...
#
# Partitioning stream reach graph...
#
# Partitioning read from reach file data/model/parallel_mesh/2023-10-19/sycMS2/sycMS2_flow_4nodes.reach
#
# Updating stream reach and node list...
# Processed 10000 nodes
# Processed 20000 nodes
# Processed 30000 nodes
# Processed 40000 nodes
# Processed 50000 nodes
# Processed 60000 nodes
# Processed 70000 nodes
# Processed 80000 nodes
# Processed 90000 nodes
# Processed 100000 nodes
#
# Updated node list based on local reaches...
# Processed 50000 edges
# Processed 100000 edges
# Processed 150000 edges
# Processed 200000 edges
# Processed 250000 edges
# Processed 300000 edges
# Processed 350000 edges
# Processed 400000 edges
# Processed 450000 edges
# Processed 500000 edges
# Processed 550000 edges
# Processed 600000 edges
#
# Updated edge list based on local reaches...
#
# Writing connectivity file...
#
#
# Part 4: Creating Resampling Object
# --------------------------------------
#
# tResample: Making boundary polygons...
#
#
# Total Number of Nodes: 		109792
#
# tResample: Making interior polygons...
#
#
# Part 4a: Creating Sheltering Object for DEM Input
# ----------------------------------------------------
#
# tResample: Making boundary polygons...
#
#
# Total Number of Nodes: 		109792
#
# tResample: Making interior polygons...
# read DEM
# OptRES = 0
# read DEM
#
#
# Part 5: Creating Output Files from 'sycMS2.in'
# ------------------------------------------
#
# Output Files:
#
#
# File  not found...
# 	Attention: The specified file with node IDs does not exist.
# 		   No node output will be written.
#
#
# >>>Outlet Node File  not found...
# >>>No output for interior nodes will be written...
#
#
#
# Part 6: Creating Hydrologic System
# --------------------------------------
#
# Resampling soil and land use grids...
# 	The file 'mdf' has been successfully read...
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2L.mdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2U.mdf'...
# 	The file 'mdf' has been successfully read...
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2L.mdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2U.mdf'...
# 	The file 'mdf' has been successfully read...
# 	The file 'mdf' has been successfully read...
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2L.mdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2U.mdf'...
#
# Hydrologic Options:
#
# Evapotranspiration Option: 	1
# Interception Option: 		2
# Ground Heat Flux Option: 	2
# Bedrock Depth Option: 		1
#
# Resampling depth to bedrock grid...
#
# HydroNodeList File  not found.
# 	Warning: The file with hydro node IDs does not exist. No output will be written.
#
# Creating Rainfall Setup...
# Rainfall Source: 		Raingauge Stations
#
# Reading Rain Gauge Station File 'data/model/rain/Rain_MS_2.sdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2L.mdf'...
#
# Reading RainGauge Data File 'data/model/rain/Rain_MS_2U.mdf'...
#
# Creating EvapoTranspiration Setup...
#
# Creating Interception Setup...
#
# Initializing SnowPack setup...
#
# Creating Restart setup...
#
#
# Part 7: Creating and Initializing Simulation
# ------------------------------------------------
#
# Proc 0: tOutput Characteristics:
# Proc 0: Number of nodes: 		109792
# Proc 0: Number of edges: 		658688
# Proc 0: Number of active nodes: 	37113
# Proc 0: Number of active edges: 	221608
# Proc 0: Number of global active nodes: 	104368
# Proc 0: Number of global active edges: 	622406
# Proc 1: tOutput Characteristics:
# Proc 1: Number of nodes: 		109792
# Proc 1: Number of edges: 		658688
# Proc 1: Number of active nodes: 	16311
# Proc 1: Number of active edges: 	97599
# Proc 1: Number of global active nodes: 	104368
# Proc 1: Number of global active edges: 	622406
# Proc 2: tOutput Characteristics:
# Proc 2: Number of nodes: 		109792
# Proc 2: Number of edges: 		658688
# Proc 2: Number of active nodes: 	15316
# Proc 2: Number of active edges: 	91007
# Proc 2: Number of global active nodes: 	104368
# Proc 2: Number of global active edges: 	622406
# Proc 3: tOutput Characteristics:
# Proc 3: Number of nodes: 		109792
# Proc 3: Number of edges: 		658688
# Proc 3: Number of active nodes: 	35628
# Proc 3: Number of active edges: 	212192
# Proc 3: Number of global active nodes: 	104368
# Proc 3: Number of global active edges: 	622406
#
# 	HOUR = 0	MINUTE = 0
#
# 	HOUR = 0	MINUTE = 0
#
# 	HOUR = 0	MINUTE = 0
#
# 	HOUR = 0	MINUTE = 0
#
# Reading HydroMeteorological Grid File: data/model/Sycamore_Weather.gdf...
#
# Using ID Land-Use Map
#
#
# Part 8: Hydrologic Simulation Loop
# --------------------------------------
#
# Hydrologic Simulation begins...
#
#
# Creating Hydrograph Output: 'results/2023-10-23/2/ms2_8760_00.mrf'
# Creating Runoff Type Output: 'results/2023-10-23/2/ms2_8760_00.rft'
#
# 	HOUR = 8760	MINUTE = 0
#
# 	HOUR = 8760	MINUTE = 0
#
# 	HOUR = 8760	MINUTE = 0
#
# 	HOUR = 8760	MINUTE = 0
# [en4201924-ssebe:48966] *** Process received signal ***
# [en4201924-ssebe:48966] Signal: Segmentation fault: 11 (11)
# [en4201924-ssebe:48966] Signal code: Invalid permissions (2)
# [en4201924-ssebe:48966] Failing at address: 0x0
# [en4201924-ssebe:48966] [ 0] 0   libsystem_platform.dylib            0x0000000186295a24 _sigtramp + 56
# [en4201924-ssebe:48966] [ 1] 0   tRIBS                               0x000000010224e9c0 _ZN11tEvapoTrans16DeleteEvapoTransEv + 128
# [en4201924-ssebe:48966] [ 2] 0   tRIBS                               0x000000010224efe4 _ZN11tEvapoTransD1Ev + 20
# [en4201924-ssebe:48966] [ 3] 0   tRIBS                               0x00000001021f1578 _Z18parallelSimulationiPPc + 4156
# [en4201924-ssebe:48966] [ 4] 0   tRIBS                               0x00000001021f0530 main + 12
# [en4201924-ssebe:48966] [ 5] 0   dyld                                0x0000000185eed058 start + 2224
# [en4201924-ssebe:48966] *** End of error message ***
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# [en4201924-ssebe:48967] *** Process received signal ***
# [en4201924-ssebe:48967] Signal: Segmentation fault: 11 (11)
# [en4201924-ssebe:48967] Signal code: Invalid permissions (2)
# [en4201924-ssebe:48967] Failing at address: 0x0
# [en4201924-ssebe:48967] [ 0] 0   libsystem_platform.dylib            0x0000000186295a24 _sigtramp + 56
# [en4201924-ssebe:48967] [ 1] 0   tRIBS                               0x0000000102c0e9c0 _ZN11tEvapoTrans16DeleteEvapoTransEv + 128
# [en4201924-ssebe:48967] [ 2] 0   tRIBS                               0x0000000102c0efe4 _ZN11tEvapoTransD1Ev + 20
# [en4201924-ssebe:48967] [ 3] 0   tRIBS                               0x0000000102bb1578 _Z18parallelSimulationiPPc + 4156
# [en4201924-ssebe:48967] [ 4] 0   tRIBS                               0x0000000102bb0530 main + 12
# [en4201924-ssebe:48967] [ 5] 0   dyld                                0x0000000185eed058 start + 2224
# [en4201924-ssebe:48967] *** End of error message ***
# [en4201924-ssebe:48964] *** Process received signal ***
# [en4201924-ssebe:48964] Signal: Segmentation fault: 11 (11)
# [en4201924-ssebe:48964] Signal code: Invalid permissions (2)
# [en4201924-ssebe:48964] Failing at address: 0x0
# [en4201924-ssebe:48964] [ 0] 0   libsystem_platform.dylib            0x0000000186295a24 _sigtramp + 56
# [en4201924-ssebe:48964] [ 1] 0   tRIBS                               0x0000000102ee69c0 _ZN11tEvapoTrans16DeleteEvapoTransEv + 128
# [en4201924-ssebe:48964] [ 2] 0   tRIBS                               0x0000000102ee6fe4 _ZN11tEvapoTransD1Ev + 20
# [en4201924-ssebe:48964] [ 3] 0   tRIBS                               0x0000000102e89578 _Z18parallelSimulationiPPc + 4156
# [en4201924-ssebe:48964] [ 4] 0   tRIBS                               0x0000000102e88530 main + 12
# [en4201924-ssebe:48964] [ 5] 0   dyld                                0x0000000185eed058 start + 2224
# [en4201924-ssebe:48964] *** End of error message ***
# [en4201924-ssebe:48965] *** Process received signal ***
# [en4201924-ssebe:48965] Signal: Segmentation fault: 11 (11)
# [en4201924-ssebe:48965] Signal code: Invalid permissions (2)
# [en4201924-ssebe:48965] Failing at address: 0x0
# [en4201924-ssebe:48965] [ 0] 0   libsystem_platform.dylib            0x0000000186295a24 _sigtramp + 56
# [en4201924-ssebe:48965] [ 1] 0   tRIBS                               0x0000000104c4e9c0 _ZN11tEvapoTrans16DeleteEvapoTransEv + 128
# [en4201924-ssebe:48965] [ 2] 0   tRIBS                               0x0000000104c4efe4 _ZN11tEvapoTransD1Ev + 20
# [en4201924-ssebe:48965] [ 3] 0   tRIBS                               0x0000000104bf1578 _Z18parallelSimulationiPPc + 4156
# [en4201924-ssebe:48965] [ 4] 0   tRIBS                               0x0000000104bf0530 main + 12
# [en4201924-ssebe:48965] [ 5] 0   dyld                                0x0000000185eed058 start + 2224
# [en4201924-ssebe:48965] *** End of error message ***
# --------------------------------------------------------------------------
# mpirun noticed that process rank 2 with PID 0 on node en4201924-ssebe exited on signal 11 (Segmentation fault: 11).
# --------------------------------------------------------------------------
#     14496.64 real     57796.60 user       162.50 sys

# %%
import pandas as pd
import numpy as np

# %%
# GW runs to look at: gwvoi in 1, gwvoi in 2, and 8700.d in 2
column_names=["ID","Nwt"]
runs = [df, pd.read_csv("results/2023-10-23/1/ms2_1_gwvoi",names=column_names,sep='\t'), pd.read_csv("results/2023-10-19/ms2_0_gwvoi",names=column_names,sep='\t')] 
titles = [0,1,2]

# %%
for run,title in zip(runs,titles):
    ax = run["Nwt"].plot(kind='hist', alpha=0.5, legend=True, label=title)
ax.set_xlabel('Nwt (mm)')
# Out:
# Text(0.5, 0, 'Nwt (mm)')

# %% [markdown]
# __Mean difference between runs 1 and 2__

# %%
# mean difference between runs 1 and 2
abs(np.mean(df.Nwt-runs[1]['Nwt']))
# Out:
# 63.77975060832439

# %% [markdown]
# __Mean difference between runs 0 and 2__

# %%
# mean difference between runs 0 and 1
abs(np.mean(runs[2]['Nwt']-runs[0]['Nwt']))
# Out:
# 254.97141703691267
